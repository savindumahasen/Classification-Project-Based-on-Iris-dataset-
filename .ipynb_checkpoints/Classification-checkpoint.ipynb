# %%
using Pkg
Pkg.add("DataFrames")
Pkg.add("CSV")
Pkg.add("MLJ")
Pkg.add("MLJBase")
Pkg.add("DecisionTree")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Manifest.toml`

# %%
## Call the library

# %%
using DataFrames
using CSV
using MLJ
using DecisionTree  # If using Decision Tree classifier

# %%
using Pkg
Pkg.add("RDatasets")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Manifest.toml`

# %%
using RDatasets

# %%
## Load the dataset

# %%
iris = dataset("datasets", "iris")
# Out:
# 150×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼─────────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa
#    4 │         4.6         3.1          1.5         0.2  setosa
#    5 │         5.0         3.6          1.4         0.2  setosa
#    6 │         5.4         3.9          1.7         0.4  setosa
#    7 │         4.6         3.4          1.4         0.3  setosa
#    8 │         5.0         3.4          1.5         0.2  setosa
#    9 │         4.4         2.9          1.4         0.2  setosa
#   10 │         4.9         3.1          1.5         0.1  setosa
#   11 │         5.4         3.7          1.5         0.2  setosa
# ...

# %%
## Print the first five recods

# %%
first(iris, 5)
# Out:
# 5×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼───────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa
#    4 │         4.6         3.1          1.5         0.2  setosa
#    5 │         5.0         3.6          1.4         0.2  setosa

# %%
using StatsPlots

# Create a scatter plot matrix (scatterplots of all feature pairs)
@df iris scatter(
    [:SepalLength, :SepalWidth, :PetalLength, :PetalWidth],  # Features to plot
    group=:Species,  # Color by species
    layout = (4, 4),  # Create a grid layout for scatterplot pairs
    legend = false,   # Hide legend
)

# %%
using Pkg
Pkg.add("MLUtils")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\THIS PC\.julia\environments\v1.10\Project.toml`
#   [f1d291b0] + MLUtils v0.4.4
#   No Changes to `C:\Users\THIS PC\.julia\environments\v1.10\Manifest.toml`

# %%
using MLUtils

# %%
# Split the dataset into 80% train and 20% test
train_data, test_data = splitobs(iris, at=0.8)

# Display the sizes of train and test datasets
println("Training Set Size: ", size(train_data))
println("Testing Set Size: ", size(test_data))
# Out:
# Training Set Size: (120,)
# Testing Set Size: (30,)
